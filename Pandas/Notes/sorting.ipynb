# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaini9/Data-Analytics-Training/blob/main/Pandas/Notes/sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Ram", "Sita", "Hari", "Gita"],
    "Age": [22, 19, 25, 21],
    "Marks": [78, 85, 67, 90]
}

df = pd.DataFrame(data)
df
# Out:
#    Name  Age  Marks
# 0   Ram   22     78
# 1  Sita   19     85
# 2  Hari   25     67
# 3  Gita   21     90

# %%
#Sort by Age
df.sort_values(by="Age")
# Out:
#    Name  Age  Marks
# 1  Sita   19     85
# 3  Gita   21     90
# 0   Ram   22     78
# 2  Hari   25     67

# %%
# Sort by Marks (descending)
df.sort_values(by="Marks")
# Out:
#    Name  Age  Marks
# 2  Hari   25     67
# 0   Ram   22     78
# 1  Sita   19     85
# 3  Gita   21     90

# %%
# First by Age, then by Marks
df.sort_values(by=["Age", "Marks"])
# Out:
#    Name  Age  Marks
# 1  Sita   19     85
# 3  Gita   21     90
# 0   Ram   22     78
# 2  Hari   25     67

# %%
df.sort_values(by=["Age", "Marks"], ascending=[True, False])
# Different order for each column:
# Out:
#    Name  Age  Marks
# 1  Sita   19     85
# 3  Gita   21     90
# 0   Ram   22     78
# 2  Hari   25     67

# %%
df.sort_index()
# sort by index
# Out:
#    Name  Age  Marks
# 0   Ram   22     78
# 1  Sita   19     85
# 2  Hari   25     67
# 3  Gita   21     90

# %%
df.sort_index(ascending=False)
# Out:
#    Name  Age  Marks
# 3  Gita   21     90
# 2  Hari   25     67
# 1  Sita   19     85
# 0   Ram   22     78

# %%
df
# Out:
#    Name  Age  Marks
# 0   Ram   22     78
# 1  Sita   19     85
# 2  Hari   25     67
# 3  Gita   21     90

# %%
# Sort and save changes (inplace)
df.sort_values(by="Marks", inplace=True)
df
# Out:
#    Name  Age  Marks
# 2  Hari   25     67
# 0   Ram   22     78
# 1  Sita   19     85
# 3  Gita   21     90

# %%
df
# Out:
#    Name  Age  Marks
# 2  Hari   25     67
# 0   Ram   22     78
# 1  Sita   19     85
# 3  Gita   21     90

# %%
# Sort strings (alphabetical order)
df.sort_values(by="Name")

# %%
# Reverse alphabetical:
df.sort_values(by="Name", ascending=False)

# %% [markdown]
# ## 🧠 Quick Summary
#
# | Task | Method |
# |------|--------|
# | Sort rows | `sort_values()` |
# | Sort index | `sort_index()` |
# | Descending order | `ascending=False` |
# | Multiple columns | `by=[...]` |
# | Save changes | `inplace=True` |
# | Fix index | `reset_index(drop=True)` |

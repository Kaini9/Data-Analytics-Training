# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaini9/Data-Analytics-Training/blob/main/Pandas/self-practice/Practicing_sorting__set__reset___use_Indexes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("/content/big4_financial_risk_compliance.csv")

# %%
df.head()
# Out:
#    Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0  2020       PwC                     2829               51
# 1  2022  Deloitte                     3589              185
# 2  2020       PwC                     2438              212
# 3  2021       PwC                     2646              397
# 4  2020       PwC                     2680              216
#
#    Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                    123                    39        Healthcare
# 1                     30                    60        Healthcare
# 2                    124                    97        Healthcare
# 3                     55                    97        Healthcare
# 4                     99                    46        Healthcare
#
#    Total_Revenue_Impact AI_Used_for_Auditing  Employee_Workload  \
# 0                114.24                   No                 57
# 1                156.98                  Yes                 58
# ...

# %%
df.describe()
# Out:
#               Year  Total_Audit_Engagements  High_Risk_Cases  \
# count   100.000000               100.000000       100.000000
# mean   2022.320000              2784.520000       277.730000
# std       1.780251              1281.863073       135.735174
# min    2020.000000               603.000000        51.000000
# 25%    2021.000000              1768.250000       162.500000
# 50%    2022.000000              2650.000000       293.000000
# 75%    2024.000000              4008.750000       395.500000
# max    2025.000000              4946.000000       500.000000
#
#        Compliance_Violations  Fraud_Cases_Detected  Total_Revenue_Impact  \
# count             100.000000            100.000000            100.000000
# mean              105.480000             52.700000            272.539000
# std                55.370101             28.311221            139.151401
# min                10.000000              5.000000             33.460000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       100 non-null    int64
#  1   Firm_Name                  100 non-null    object
#  2   Total_Audit_Engagements    100 non-null    int64
#  3   High_Risk_Cases            100 non-null    int64
#  4   Compliance_Violations      100 non-null    int64
#  5   Fraud_Cases_Detected       100 non-null    int64
#  6   Industry_Affected          100 non-null    object
#  7   Total_Revenue_Impact       100 non-null    float64
#  8   AI_Used_for_Auditing       100 non-null    object
#  9   Employee_Workload          100 non-null    int64
#  10  Audit_Effectiveness_Score  100 non-null    float64
#  11  Client_Satisfaction_Score  100 non-null    float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 9.5+ KB

# %% [markdown]
# SORTING

# %% [markdown]
# LA FRAUD CASES ANUSAR SORT GARAM

# %%
df.sort_values(by="Fraud_Cases_Detected")
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 75  2021            PwC                     1078              395
# 45  2020  Ernst & Young                     4570              284
# 94  2023  Ernst & Young                     4895              123
# 10  2020           KPMG                     1497              330
# 23  2024  Ernst & Young                     1760              415
# ..   ...            ...                      ...              ...
# 97  2021       Deloitte                     3810              463
# 3   2021            PwC                     2646              397
# 2   2020            PwC                     2438              212
# 91  2023           KPMG                     2919              453
# 59  2024       Deloitte                     1275              201
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 75                     58                     5              Tech
# ...

# %% [markdown]
# LA ABA FRAUD CASES LAI DESENDING MA HERUM HAI TA

# %%
df.sort_values(by="Fraud_Cases_Detected",  ascending=False)
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 59  2024       Deloitte                     1275              201
# 91  2023           KPMG                     2919              453
# 3   2021            PwC                     2646              397
# 2   2020            PwC                     2438              212
# 97  2021       Deloitte                     3810              463
# ..   ...            ...                      ...              ...
# 23  2024  Ernst & Young                     1760              415
# 10  2020           KPMG                     1497              330
# 94  2023  Ernst & Young                     4895              123
# 45  2020  Ernst & Young                     4570              284
# 75  2021            PwC                     1078              395
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 59                     20                   100            Retail
# ...

# %% [markdown]
# ABA FRAUD CASES PAHILA RA TESPAXI Client Satisfaction HAI TA

# %%
df.sort_values(by=["Fraud_Cases_Detected","Client_Satisfaction_Score"])
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 75  2021            PwC                     1078              395
# 45  2020  Ernst & Young                     4570              284
# 10  2020           KPMG                     1497              330
# 94  2023  Ernst & Young                     4895              123
# 6   2022       Deloitte                     1199              148
# ..   ...            ...                      ...              ...
# 97  2021       Deloitte                     3810              463
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 91  2023           KPMG                     2919              453
# 59  2024       Deloitte                     1275              201
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 75                     58                     5              Tech
# ...

# %% [markdown]
# lets check only that two column with name

# %%
df[["Fraud_Cases_Detected","Firm_Name", "Client_Satisfaction_Score"]].sort_values(by=["Fraud_Cases_Detected", "Client_Satisfaction_Score"])
# Out:
#     Fraud_Cases_Detected      Firm_Name  Client_Satisfaction_Score
# 75                     5            PwC                        5.9
# 45                     6  Ernst & Young                        6.1
# 10                    10           KPMG                        8.0
# 94                    10  Ernst & Young                        8.4
# 6                     11       Deloitte                        6.3
# ..                   ...            ...                        ...
# 97                    96       Deloitte                        6.5
# 2                     97            PwC                        6.2
# 3                     97            PwC                        8.6
# 91                    99           KPMG                        5.1
# 59                   100       Deloitte                        7.8
#
# [100 rows x 3 columns]

# %% [markdown]
# Lets sort the indexes

# %%
df.sort_index()
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2021  Deloitte                      603               62
# 1   2020  Deloitte                     1925              189
# 2   2022  Deloitte                      962              356
# 3   2020  Deloitte                     2030              200
# 4   2022  Deloitte                     4287              158
# ..   ...       ...                      ...              ...
# 95  2020       PwC                     4401              249
# 96  2023       PwC                     2283               58
# 97  2021       PwC                     1078              395
# 98  2024       PwC                     4103              423
# 99  2021       PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     100                    20              Tech
# 1                      39                    52              Tech
# ...

# %% [markdown]
# lets acess deliotee from firm name second by loc iloc

# %% [markdown]
# ILOC

# %% [markdown]
# 3rd row ko colunm ra 1,6 lai print garnum

# %%
df.iloc[3, [1, 6]]
# Out:
# Firm_Name              Deloitte
# Industry_Affected    Healthcare
# Name: 3, dtype: object

# %%
df.iloc[1,1]
# Out:
# 'Deloitte'

# %% [markdown]
# get get 189 from high risk

# %%
df.iloc[1,3]
# Out:
# np.int64(189)

# %% [markdown]
# by LOC

# %%
df.loc[3, ["Firm_Name", "Industry_Affected"]]
# Out:
# Firm_Name              Deloitte
# Industry_Affected    Healthcare
# Name: 3, dtype: object

# %%
df.loc[1,"Firm_Name"]
# Out:
# 'Deloitte'

# %%
df.loc[1,"High_Risk_Cases"]
# Out:
# np.int64(189)

# %% [markdown]
# LETS USE CONDITIONS

# %%
df.loc[df["High_Risk_Cases"] >60, ["Firm_Name", "Industry_Affected"]]
# Out:
#    Firm_Name Industry_Affected
# 0   Deloitte              Tech
# 1   Deloitte              Tech
# 2   Deloitte           Finance
# 3   Deloitte        Healthcare
# 4   Deloitte        Healthcare
# ..       ...               ...
# 94       PwC           Finance
# 95       PwC           Finance
# 97       PwC              Tech
# 98       PwC        Healthcare
# 99       PwC           Finance
#
# [96 rows x 2 columns]

# %% [markdown]
# 300 vanda badi risk huda only in deloitte reveneu impact herum

# %%
df.loc[(df["Firm_Name"]=="Deloitte") & (df["High_Risk_Cases"]> 300),["Industry_Affected","Firm_Name","High_Risk_Cases","Total_Revenue_Impact"]]
# Out:
#    Industry_Affected Firm_Name  High_Risk_Cases  Total_Revenue_Impact
# 2            Finance  Deloitte              356                 54.07
# 5         Healthcare  Deloitte              483                284.84
# 6         Healthcare  Deloitte              481                 83.61
# 7             Retail  Deloitte              360                432.80
# 11        Healthcare  Deloitte              354                160.31
# 12              Tech  Deloitte              313                110.06
# 13              Tech  Deloitte              367                334.56
# 16           Finance  Deloitte              449                263.14
# 17        Healthcare  Deloitte              382                268.67
# 18           Finance  Deloitte              406                140.29
# 23        Healthcare  Deloitte              463                349.04
# 25        Healthcare  Deloitte              469                418.49
# ...

# %% [markdown]
# Lets use inplace = true

# %%
df.sort_values(by=["Fraud_Cases_Detected", "Client_Satisfaction_Score",],inplace=True)

# %% [markdown]
# now it changed perm

# %%
df[["Fraud_Cases_Detected","Firm_Name", "Client_Satisfaction_Score"]]
# Out:
#     Fraud_Cases_Detected      Firm_Name  Client_Satisfaction_Score
# 75                     5            PwC                        5.9
# 45                     6  Ernst & Young                        6.1
# 10                    10           KPMG                        8.0
# 94                    10  Ernst & Young                        8.4
# 6                     11       Deloitte                        6.3
# ..                   ...            ...                        ...
# 97                    96       Deloitte                        6.5
# 2                     97            PwC                        6.2
# 3                     97            PwC                        8.6
# 91                    99           KPMG                        5.1
# 59                   100       Deloitte                        7.8
#
# [100 rows x 3 columns]

# %% [markdown]
# now lets sort by name accending and decending

# %%
df.sort_index(inplace=True)

# %% [markdown]
# decending

# %%
df.sort_values(by="Firm_Name", ascending=False)
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020       PwC                     2829               51
# 75  2021       PwC                     1078              395
# 25  2025       PwC                     4470               63
# 36  2023       PwC                     3449              102
# 40  2020       PwC                     3981              199
# ..   ...       ...                      ...              ...
# 52  2020  Deloitte                      995              354
# 54  2021  Deloitte                     1992              313
# 57  2025  Deloitte                     4390              367
# 63  2025  Deloitte                     2208              296
# 59  2024  Deloitte                     1275              201
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# 75                     58                     5              Tech
# ...

# %%
df.sort_values(by="Firm_Name", ascending=True)
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 39  2021  Deloitte                      603               62
# 90  2020  Deloitte                     1925              189
# 89  2022  Deloitte                      962              356
# 30  2020  Deloitte                     2030              200
# 34  2022  Deloitte                     4287              158
# ..   ...       ...                      ...              ...
# 58  2020       PwC                     4401              249
# 70  2023       PwC                     2283               58
# 75  2021       PwC                     1078              395
# 24  2024       PwC                     4103              423
# 99  2021       PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 39                    100                    20              Tech
# 90                     39                    52              Tech
# ...

# %% [markdown]
# RESET

# %% [markdown]
# index fromm 0  ra name anusar sort

# %%
df.sort_values(by="Firm_Name", inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2021  Deloitte                      603               62
# 1   2020  Deloitte                     1925              189
# 2   2022  Deloitte                      962              356
# 3   2020  Deloitte                     2030              200
# 4   2022  Deloitte                     4287              158
# ..   ...       ...                      ...              ...
# 95  2020       PwC                     4401              249
# 96  2023       PwC                     2283               58
# 97  2021       PwC                     1078              395
# 98  2024       PwC                     4103              423
# 99  2021       PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     100                    20              Tech
# 1                      39                    52              Tech
# ...

# %% [markdown]
# LETS SET INDEX BY NAME

# %%
df.set_index("Firm_Name")
# Out:
#            Year  Total_Audit_Engagements  High_Risk_Cases  \
# Firm_Name
# Deloitte   2021                      603               62
# Deloitte   2020                     1925              189
# Deloitte   2022                      962              356
# Deloitte   2020                     2030              200
# Deloitte   2022                     4287              158
# ...         ...                      ...              ...
# PwC        2020                     4401              249
# PwC        2023                     2283               58
# PwC        2021                     1078              395
# PwC        2024                     4103              423
# PwC        2021                     4473              195
#
#            Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# Firm_Name
# Deloitte                     100                    20              Tech
# Deloitte                      39                    52              Tech
# ...

# %%
df
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2021  Deloitte                      603               62
# 1   2020  Deloitte                     1925              189
# 2   2022  Deloitte                      962              356
# 3   2020  Deloitte                     2030              200
# 4   2022  Deloitte                     4287              158
# ..   ...       ...                      ...              ...
# 95  2020       PwC                     4401              249
# 96  2023       PwC                     2283               58
# 97  2021       PwC                     1078              395
# 98  2024       PwC                     4103              423
# 99  2021       PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     100                    20              Tech
# 1                      39                    52              Tech
# ...

# %% [markdown]
# PERMANENTLY NOT CHANGED LETS USE INPLACE=TRUE

# %%
df.set_index("Firm_Name", inplace=True)

# %%
df
# Out:
#            Year  Total_Audit_Engagements  High_Risk_Cases  \
# Firm_Name
# Deloitte   2021                      603               62
# Deloitte   2020                     1925              189
# Deloitte   2022                      962              356
# Deloitte   2020                     2030              200
# Deloitte   2022                     4287              158
# ...         ...                      ...              ...
# PwC        2020                     4401              249
# PwC        2023                     2283               58
# PwC        2021                     1078              395
# PwC        2024                     4103              423
# PwC        2021                     4473              195
#
#            Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# Firm_Name
# Deloitte                     100                    20              Tech
# Deloitte                      39                    52              Tech
# ...

# %% [markdown]
# NOW LETS RESET INDEX

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    Firm_Name  Year  Total_Audit_Engagements  High_Risk_Cases  \
# 0   Deloitte  2021                      603               62
# 1   Deloitte  2020                     1925              189
# 2   Deloitte  2022                      962              356
# 3   Deloitte  2020                     2030              200
# 4   Deloitte  2022                     4287              158
# ..       ...   ...                      ...              ...
# 95       PwC  2020                     4401              249
# 96       PwC  2023                     2283               58
# 97       PwC  2021                     1078              395
# 98       PwC  2024                     4103              423
# 99       PwC  2021                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     100                    20              Tech
# 1                      39                    52              Tech
# ...
